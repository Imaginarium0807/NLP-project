# %%
from gensim.models import Phrases
from nltk.corpus import stopwords
import gensim
import gensim.corpora as corpora
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
stop = stopwords.words("english")

# %%
path = 'categories/indian.txt'
sent_stream = []
doc_stream = []
with open(path, 'rt', encoding='UTF8') as rf:
    for line in rf:
        line=' '.join([word.lower() for word in line.split()])
        line=' '.join([word for word in line.split() if word.isalpha()])
        line=' '.join([word for word in line.split() if word not in stop])
        sent_stream.append(line.split(' '))

# %%
phrases = Phrases(sent_stream, min_count=1, threshold=1)  # train model
texts = [phrases[line] for line in sent_stream]

# %%
new_corpus = []
for doc in texts:
    new_corpus.append(' '.join(doc))

# %%
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(new_corpus)

# %%
terms = vectorizer.get_feature_names()

# sum tfidf frequency of each term through documents
sums = X.sum(axis=0)

# connecting term to its sums frequency
data = []
for col, term in enumerate(terms):
    data.append( (term, sums[0,col] ))

ranking = pd.DataFrame(data, columns=['term','rank'])
ranked_list = ranking.sort_values(by=['rank'], ascending=False)

# %%
ranked_list.values.tolist()[:500]
# Out:
# [['food', 423.1447201710221],
#  ['good', 291.9226699804169],
#  ['place', 275.0935513890877],
#  ['indian', 244.39774677209417],
#  ['like', 214.27074823686664],
#  ['buffet', 206.71108987474324],
#  ['great', 197.51790627110472],
#  ['one', 179.21853780939534],
#  ['restaurant', 173.43486856560492],
#  ['indian_food', 164.14997557462152],
#  ['go', 160.6871807823421],
#  ['service', 159.74077805559887],
#  ['lunch_buffet', 153.81819476695347],
#  ['get', 151.28508720306675],
#  ['lunch', 144.84054746858217],
#  ['also', 140.483831111547],
#  ['really', 138.12602898979395],
#  ['chicken', 137.190181287967],
#  ['chicken_tikka', 130.1810812441697],
#  ['naan', 128.70516648482504],
#  ['back', 122.08365806948268],
#  ['try', 121.54671457140996],
#  ['little', 119.70761762499957],
#  ['love', 118.47120343383607],
#  ['nice', 112.52799800194586],
#  ['even', 112.00902423854626],
#  ['dishes', 109.41928926011214],
#  ['best_indian', 103.60905130705686],
#  ['dinner', 101.06179396049083],
#  ['best', 100.285008892439],
#  ['would', 97.72808933680238],
#  ['time', 94.46049758048112],
#  ['garlic_naan', 93.8756654297704],
#  ['curry', 90.50211436986848],
#  ['got', 89.69624578513418],
#  ['eat', 89.13705759393974],
#  ['ordered', 88.76719496290401],
#  ['definitely', 88.3884274036128],
#  ['think', 88.15783695739478],
#  ['much', 86.41905544582995],
#  ['masala', 85.03809297583037],
#  ['always', 83.6356013144638],
#  ['rice', 82.91339359457467],
#  ['order', 82.57507385428327],
#  ['went', 82.2160586850765],
#  ['well', 80.5148063193061],
#  ['menu', 79.86913968678942],
#  ['come', 79.84244637233961],
#  ['still', 77.97497899364812],
#  ['bit', 77.74377345215426],
#  ['know', 75.24258153639816],
#  ['delicious', 74.70685359202514],
#  ['everything', 73.94758809797112],
#  ['first', 73.83787574717786],
#  ['going', 73.16738232043318],
#  ['came', 72.37970118835186],
#  ['say', 70.16476399838528],
#  ['staff', 70.10088946841539],
#  ['pretty', 69.66133134867337],
#  ['us', 69.63078654604963],
#  ['tried', 68.87907885118297],
#  ['spicy', 66.94242997480022],
#  ['made', 66.93827165535048],
#  ['stars', 66.47061412236096],
#  ['never', 66.21052349021554],
#  ['better', 65.70964050497076],
#  ['since', 64.97470795212716],
#  ['dish', 64.32575030031627],
#  ['lamb', 63.84030165878472],
#  ['indian_restaurant', 63.599032295308774],
#  ['quite', 63.05481025453389],
#  ['ever', 62.937893547954914],
#  ['taste', 62.576998524475385],
#  ['indian_restaurants', 62.56631025802193],
#  ['garlic', 61.97347082300563],
#  ['two', 60.9378899052814],
#  ['take', 60.63193023541],
#  ['excellent', 60.59672124686779],
#  ['make', 60.08965623385813],
#  ['sure', 59.98574578268319],
#  ['tandoori_chicken', 58.590214735071456],
#  ['give', 57.79047896670953],
#  ['new', 57.13144341783347],
#  ['right', 56.693818541450554],
#  ['could', 56.62842213803876],
#  ['tasty', 56.37008146776411],
#  ['next', 56.36222948606583],
#  ['vegetarian', 55.9047307203494],
#  ['first_time', 55.398685837588154],
#  ['meal', 54.998632125873236],
#  ['way', 54.993811034186464],
#  ['see', 54.78297763540234],
#  ['eating', 54.571774688479344],
#  ['friendly', 54.490963735189816],
#  ['restaurants', 53.83859724517119],
#  ['around', 53.377990210437815],
#  ['full', 53.36654793065687],
#  ['people', 52.73731033408959],
#  ['bad', 52.59558280864034],
#  ['found', 52.51584061508122],
#  ['want', 51.90778681306041],
#  ['experience', 51.37017144929936],
#  ['lot', 50.57758168498114],
#  ['worth', 50.4230286021884],
#  ['hot', 50.25520612526698],
#  ['fresh', 49.89596426554165],
#  ['tikka_masala', 49.85517413071559],
#  ['amazing', 49.78257541766009],
#  ['probably', 49.239969400452416],
#  ['find', 49.07716324279542],
#  ['good_indian', 48.68523206858011],
#  ['times', 48.07396942762817],
#  ['kind', 47.54877651714493],
#  ['price', 47.27235403622877],
#  ['table', 46.80069826187925],
#  ['something', 46.44341072450882],
#  ['go_back', 46.345499519028344],
#  ['small', 46.287000350460296],
#  ['things', 45.86472283734569],
#  ['different', 45.73890593515892],
#  ['served', 45.53914137336632],
#  ['recommend', 45.33153602052956],
#  ['mango', 45.31496229406197],
#  ['places', 45.157036500497995],
#  ['loved', 45.098706625266864],
#  ['said', 45.087025404919835],
#  ['maybe', 44.86351723469412],
#  ['vegas', 44.43537909812913],
#  ['though', 44.31654118742252],
#  ['sauce', 44.02211531885565],
#  ['thought', 43.530870875686],
#  ['happy', 43.25613320448813],
#  ['although', 43.20359578624154],
#  ['owner', 43.06784385148672],
#  ['many', 42.837095959426634],
#  ['used', 42.57966723174365],
#  ['food_good', 42.5158054992345],
#  ['big', 41.77222990914378],
#  ['flavor', 41.580413014727675],
#  ['tandoori', 41.21888647770006],
#  ['actually', 41.14691490839777],
#  ['check', 40.982082182285716],
#  ['asked', 39.96409819190198],
#  ['quality', 39.76197326947687],
#  ['great_food', 39.62921266607726],
#  ['items', 39.55537935108022],
#  ['side', 39.49017262575457],
#  ['enough', 39.227743952543165],
#  ['prices', 39.210789626528765],
#  ['looking', 39.07330751635542],
#  ['another', 39.05312047878769],
#  ['mango_lassi', 39.03982180402003],
#  ['especially', 38.903181825635066],
#  ['took', 38.79583139728234],
#  ['review', 38.773461380923756],
#  ['spice', 38.67190407289189],
#  ['india', 38.52667855196545],
#  ['night', 38.46255673005799],
#  ['really_good', 38.391011038422896],
#  ['family', 38.319655138580195],
#  ['one_best', 38.025298028896074],
#  ['enjoyed', 37.983705898048335],
#  ['friend', 37.90986229827857],
#  ['atmosphere', 37.89197741084739],
#  ['paneer', 37.698233867260704],
#  ['meat', 37.61281084517306],
#  ['favorite_indian', 37.26157027145694],
#  ['tikka', 37.24914033510551],
#  ['every', 37.144819694542264],
#  ['favorite', 37.00823632893411],
#  ['day', 36.8930744188895],
#  ['nothing', 36.82945249382495],
#  ['bread', 36.806649835628235],
#  ['food_service', 36.70779231870135],
#  ['without', 36.59250906169377],
#  ['last', 36.52751152622566],
#  ['decor', 36.447584108508266],
#  ['coming', 36.34489064775113],
#  ['ate', 36.136318464149625],
#  ['must', 36.01028572642522],
#  ['love_indian', 35.9736139080806],
#  ['may', 35.868523696176595],
#  ['south_indian', 35.843281928231406],
#  ['waiter', 35.77255303694236],
#  ['far', 35.70964651218828],
#  ['long', 35.67332442826085],
#  ['dessert', 35.64795319043628],
#  ['like_indian', 35.63817659449317],
#  ['top', 35.14178312458539],
#  ['close', 35.0537914742278],
#  ['enjoy', 34.94398553912808],
#  ['highly_recommend', 34.86008602821654],
#  ['least', 34.84805498154847],
#  ['visit', 34.69832787159383],
#  ['oh', 34.682080232198345],
#  ['vegetable', 34.32862288036392],
#  ['awesome', 34.2509345238818],
#  ['flavors', 34.164773791156556],
#  ['almost', 33.91836117205156],
#  ['ask', 33.814207244638666],
#  ['less', 33.803050351366174],
#  ['usually', 33.707144556491905],
#  ['feel', 33.49546747550452],
#  ['couple', 33.378994464769626],
#  ['husband', 33.26475426035135],
#  ['butter_chicken', 33.23543739245589],
#  ['dining', 33.223801244630636],
#  ['super', 33.09774164228768],
#  ['huge', 33.02211599443502],
#  ['curries', 32.87823649818967],
#  ['liked', 32.863215171275414],
#  ['yelp', 32.75246672849841],
#  ['star', 32.63878884516326],
#  ['bring', 32.6251254352118],
#  ['good_food', 32.49186833010157],
#  ['open', 32.402877563442786],
#  ['look', 32.283965303946665],
#  ['weekday_lunch', 32.081818798085536],
#  ['overall', 31.949329491183086],
#  ['staff_friendly', 31.944884160684833],
#  ['absolutely', 31.825129213625225],
#  ['server', 31.68966976719507],
#  ['large', 31.619874348807507],
#  ['need', 31.555615058919955],
#  ['dosa', 31.550509098515725],
#  ['mint', 31.367390870295818],
#  ['naan_bread', 31.31707434775402],
#  ['wait', 31.165698689740772],
#  ['tasted', 31.14309598580296],
#  ['food_really', 31.143005091836134],
#  ['rather', 30.988349899805286],
#  ['chicken_curry', 30.948137941245484],
#  ['told', 30.809585674916917],
#  ['options', 30.711747693489972],
#  ['would_definitely', 30.700154192172175],
#  ['clean', 30.64673561029125],
#  ['wonderful', 30.645623402757316],
#  ['friends', 30.600691192137447],
#  ['went_lunch', 30.57417632945868],
#  ['sweet', 30.52245628189955],
#  ['ok', 30.32237626422735],
#  ['even_though', 30.279578281701376],
#  ['highly', 30.139942063108187],
#  ['would_recommend', 30.08865945101163],
#  ['cooked', 30.02574911524877],
#  ['special', 29.92471830719045],
#  ['left', 29.839798877498815],
#  ['perfect', 29.79842503861532],
#  ['might', 29.793701870169265],
#  ['real', 29.75772962816767],
#  ['spices', 29.627859529565324],
#  ['thing', 29.59764046403924],
#  ['brought', 29.439952130217616],
#  ['area', 29.305928829165563],
#  ['anything', 29.147418277996533],
#  ['veggie', 29.10258316188514],
#  ['decent', 28.878042340044907],
#  ['closed', 28.85783943749515],
#  ['variety', 28.815781918186797],
#  ['reasonable', 28.69956963436806],
#  ['las', 28.660388676794973],
#  ['use', 28.653473760066042],
#  ['water', 28.6365777085835],
#  ['seemed', 28.58983514298268],
#  ['part', 28.479456693489386],
#  ['drink', 28.428873026407786],
#  ['flavorful', 28.3727353819779],
#  ['samosas', 28.354838006181602],
#  ['fantastic', 28.323049052821617],
#  ['great_service', 28.311345017398374],
#  ['home', 28.291068616208282],
#  ['cuisine', 28.284307663364395],
#  ['getting', 28.100811062227443],
#  ['great_place', 28.000017276721533],
#  ['inside', 27.960250372643166],
#  ['every_time', 27.860524996978995],
#  ['lots', 27.859842532525114],
#  ['location', 27.75237732527872],
#  ['tables', 27.66768988937136],
#  ['wife', 27.643427153165206],
#  ['serve', 27.537039985517023],
#  ['disappointed', 27.500639659136027],
#  ['selection', 27.487314614916272],
#  ['make_sure', 27.427067666994308],
#  ['old', 27.370625138847885],
#  ['sauces', 27.32718596327224],
#  ['las_vegas', 27.24654490791608],
#  ['food_great', 27.181739339607915],
#  ['makes', 27.17793672989894],
#  ['yet', 27.14488094300722],
#  ['eaten', 27.12406798648621],
#  ['ordered_chicken', 26.972503033802408],
#  ['started', 26.921924298970648],
#  ['trying', 26.84306423282969],
#  ['samosa', 26.839374871235016],
#  ['next_time', 26.822971250510065],
#  ['wanted', 26.812267072072295],
#  ['put', 26.781798101730498],
#  ['plus', 26.675668182410284],
#  ['serving', 26.63136882168085],
#  ['comes', 26.438086403609184],
#  ['stuff', 26.242849198953184],
#  ['service_friendly', 26.233406286686552],
#  ['glad', 26.215974348982442],
#  ['portions', 26.16874861004197],
#  ['going_back', 26.1660735066422],
#  ['extremely', 26.033108720280577],
#  ['keep', 26.023990023790372],
#  ['either', 25.981793588495844],
#  ['seem', 25.860201579261865],
#  ['three', 25.82989872518933],
#  ['away', 25.652545000944553],
#  ['main', 25.606889756712768],
#  ['pretty_good', 25.606786277922645],
#  ['would_go', 25.544791499637792],
#  ['buffets', 25.444042145102195],
#  ['offer', 25.426514393088446],
#  ['come_back', 25.410425449958833],
#  ['let', 25.09843010022185],
#  ['indian_buffet', 25.070248884033845],
#  ['really_enjoyed', 25.055954089633524],
#  ['quick', 24.90917974788294],
#  ['gave', 24.87684418131335],
#  ['ordering', 24.800023730822044],
#  ['half', 24.78079486574818],
#  ['however', 24.763784599134656],
#  ['hard', 24.63834773221682],
#  ['better_indian', 24.615268771113897],
#  ['fact', 24.597515156731266],
#  ['authentic', 24.587978078011623],
#  ['stop', 24.56527131610469],
#  ['high', 24.492510369424334],
#  ['remember', 24.323626535972856],
#  ['lovely', 24.284751688111424],
#  ['much_better', 24.220916289327434],
#  ['done', 24.106736240068592],
#  ['biryani', 24.05509784927028],
#  ['certainly', 23.978610965496166],
#  ['minutes', 23.898094089039244],
#  ['wish', 23.868527284205385],
#  ['saag_paneer', 23.859500996757614],
#  ['regular', 23.81732219421593],
#  ['goat', 23.620975922168558],
#  ['guess', 23.434190871955476],
#  ['work', 23.41634040806852],
#  ['simply', 23.41165696953929],
#  ['given', 23.294692005636524],
#  ['great_indian', 23.258071255110625],
#  ['free', 23.206510069564803],
#  ['cheap', 23.200675129778897],
#  ['decided', 23.185080597867312],
#  ['everyone', 23.159700353039813],
#  ['seems', 23.109232238038913],
#  ['expect', 23.105336010129278],
#  ['end', 23.031940544525987],
#  ['believe', 22.933495664655858],
#  ['tell', 22.884498303988828],
#  ['return', 22.83149813195199],
#  ['service_good', 22.570820521689512],
#  ['instead', 22.453176211410245],
#  ['extra', 22.406090039831625],
#  ['strip', 22.393210387976943],
#  ['saw', 22.380897764366818],
#  ['vindaloo', 22.380436493224117],
#  ['basmati_rice', 22.376863640600256],
#  ['plate', 22.374573469009018],
#  ['often', 22.324985026293604],
#  ['mostly', 22.28454312991747],
#  ['several', 22.279168679370198],
#  ['saag', 22.270190604969134],
#  ['authentic_indian', 22.05587015025363],
#  ['indian_place', 22.050558303993363],
#  ['miss', 22.034292066784683],
#  ['one_favorite', 21.969239883223462],
#  ['whole', 21.960588936284825],
#  ['beer', 21.953156611866074],
#  ['low', 21.871950723819598],
#  ['along', 21.762929411921483],
#  ['entrees', 21.713597343486235],
#  ['walked', 21.393765167216987],
#  ['plain', 21.273570949272937],
#  ['start', 21.26497087246402],
#  ['sometimes', 21.26271129304993],
#  ['someone', 21.19534597026802],
#  ['value', 21.178844492497632],
#  ['care', 21.073404223903932],
#  ['group', 21.06206921739999],
#  ['great_great', 21.05042527273373],
#  ['reviews', 20.878140979556463],
#  ['arrived', 20.862474748880103],
#  ['nan', 20.82864430017189],
#  ['chutney', 20.80060781044669],
#  ['business', 20.764850655854627],
#  ['course', 20.75775239582684],
#  ['making', 20.750103252196745],
#  ['outside', 20.74264807226168],
#  ['offered', 20.701024931493478],
#  ['appetizer', 20.698714281273844],
#  ['near', 20.679081564398743],
#  ['rice_pudding', 20.5970365257298],
#  ['craving_indian', 20.58958706410945],
#  ['phoenix', 20.55331051591146],
#  ['butter', 20.52371892528223],
#  ['definitely_go', 20.4623741077926],
#  ['vegan', 20.41960873393816],
#  ['today', 20.41268096385103],
#  ['dry', 20.389248561312925],
#  ['looked', 20.330274262323538],
#  ['pay', 20.324601923105742],
#  ['korma', 20.288923932516973],
#  ['drinks', 20.22742925352303],
#  ['felt', 20.170516308676085],
#  ['really_like', 20.07960010093061],
#  ['pretty_much', 20.055174363874077],
#  ['well_worth', 20.005830291039235],
#  ['ambiance', 19.97199670833515],
#  ['years', 19.953396999394204],
#  ['food_ever', 19.940472862167375],
#  ['little_bit', 19.936424431270904],
#  ['fan', 19.849101767190874],
#  ['thank', 19.840881872549556],
#  ['tasted_like', 19.816919239099246],
#  ['based', 19.80866430282116],
#  ['wait_go', 19.76384502839304],
#  ['gone', 19.719823926239208],
#  ['already', 19.673883929255368],
#  ['needed', 19.64821855829213],
#  ['cold', 19.62387537359374],
#  ['totally', 19.5642531787343],
#  ['service_food', 19.54960472042033],
#  ['filled', 19.50770150840476],
#  ['food_pretty', 19.5051074646093],
#  ['pleasant', 19.466547863622402],
#  ['slightly', 19.466443742844163],
#  ['finally', 19.342182986867932],
#  ['dhaba', 19.341813925721308],
#  ['perhaps', 19.334266577323035],
#  ['rest', 19.32804907339158],
#  ['call', 19.304632699251574],
#  ['plates', 19.28284703161506],
#  ['coming_back', 19.273729891837743],
#  ['walk', 19.270786396714016],
#  ['good_place', 19.215938347491576],
#  ['food_always', 19.190416863879086],
#  ['malai_kofta', 19.173468806059223],
#  ['service_great', 19.169662704474558],
#  ['slow', 19.15407351348833],
#  ['bar', 19.135757589224635],
#  ['indian_cuisine', 19.121868388963883],
#  ['point', 19.05294349697232],
#  ['due', 19.031823773502172],
#  ['choices', 18.99007276093916],
#  ['definitely_back', 18.96060524651745],
#  ['owners', 18.89721935602134],
#  ['mixed', 18.87058887348406],
#  ['spot', 18.85976726152199],
#  ['attentive', 18.835441541738923],
#  ['cool', 18.834900269681725],
#  ['india_palace', 18.825375440798254],
#  ['mention', 18.76330171821808],
#  ['pick', 18.7564851814664],
#  ['town', 18.73831714406622],
#  ['lassi', 18.688010663091283],
#  ['kitchen', 18.684750656594506],
#  ['name', 18.6782638837291],
#  ['choice', 18.662261912614877],
#  ['indian_places', 18.641849320795348],
#  ['exactly', 18.6164934254845],
#  ['busy', 18.61371843197074],
#  ['type', 18.57370307246371],
#  ['hope', 18.564608977459287],
#  ['meals', 18.539362343134556],
#  ['days', 18.524585875532658],
#  ['servers', 18.49146919170062],
#  ['cheese', 18.448029251050997],
#  ['including', 18.431215021396106],
#  ['bill', 18.41132513916192],
#  ['person', 18.39033280726879],
#  ['sit', 18.32132938984163],
#  ['simple', 18.288363397093086],
#  ['warm', 18.281239050319975],
#  ['palak_paneer', 18.277890714557522],
#  ['expensive', 18.258794621471278],
#  ['hit', 18.234131295401806],
#  ['stopped', 18.207264766125217],
#  ['light', 18.170782346482337],
#  ['appetizers', 18.1604256082036],
#  ['groupon', 18.12214489352401],
#  ['back_try', 18.120217302501846],
#  ['salad', 18.112160572005184],
#  ['also_ordered', 18.084479497463313],
#  ['live', 18.017450688205486],
#  ['week', 17.99808955637923],
#  ['fish', 17.98645842423976],
#  ['quality_food', 17.98000329469829],
#  ['set', 17.92869235086306],
#  ['customers', 17.928178547124134],
#  ['entree', 17.92015424960746],
#  ['help', 17.902251478866088],
#  ['choose', 17.88366475124111]]

# %% [markdown]
# LDA Model

# %%
id2word = corpora.Dictionary(texts)
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('bit', 1),
#   ('buffet', 1),
#   ('buffet_dollars', 1),
#   ('crazy_weekend', 1),
#   ('dinner', 1),
#   ('food_still', 1),
#   ('good', 1),
#   ('great', 1),
#   ('happy', 1),
#   ('happy_belly', 1),
#   ('location', 1),
#   ('lunch_buffet', 1),
#   ('odana_rd', 1),
#   ('price', 1),
#   ('recently_went', 1),
#   ('stick_lunch', 1),
#   ('take_leave', 1),
#   ('try_little', 1),
#   ('west_side', 1)]]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20) 
#                                            random_state=100,
#                                            update_every=1,
#                                            chunksize=30,
#                                            passes=10,
#                                            alpha='auto',
#                                            per_word_topics=True)

# %%
from pprint import pprint
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics(num_topics=20, num_words=30))
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.025*"food" + 0.021*"chicken_tikka" + 0.019*"one" + 0.016*"masala" + '
#   '0.016*"got" + 0.015*"like" + 0.012*"came" + 0.012*"try" + 0.011*"chicken" + '
#   '0.010*"place" + 0.010*"think" + 0.010*"dish" + 0.009*"good" + 0.009*"sauce" '
#   '+ 0.009*"really" + 0.009*"tried" + 0.009*"also" + 0.009*"amazing" + '
#   '0.008*"much" + 0.008*"dishes" + 0.008*"know" + 0.007*"ordered" + '
#   '0.007*"first" + 0.007*"curry" + 0.006*"indian" + 0.006*"buffet" + '
#   '0.006*"back" + 0.006*"little" + 0.006*"great" + 0.006*"meat"'),
#  (1,
#   '0.026*"items" + 0.024*"stars" + 0.020*"owner" + 0.019*"friendly" + '
#   '0.018*"offer" + 0.016*"oh" + 0.015*"wish" + 0.015*"already" + 0.014*"time" '
#   '+ 0.014*"prices" + 0.011*"much_better" + 0.010*"family" + 0.010*"ok" + '
#   '0.010*"reasonable" + 0.010*"level" + 0.010*"generous" + 0.009*"tastes" + '
#   '0.009*"prepared" + 0.008*"opening" + 0.008*"indian_food" + '
#   '0.008*"service_great" + 0.008*"knowing" + 0.008*"compared" + '
#   '0.007*"horrible" + 0.007*"shared" + 0.007*"kind" + 0.007*"easy" + '
#   '0.006*"offering" + 0.006*"showed" + 0.006*"decided_give"'),
#  (2,
#   '0.021*"rice" + 0.017*"paneer" + 0.015*"goat" + 0.015*"recommend" + '
#   '0.014*"variety" + 0.014*"good_food" + 0.013*"say" + 0.011*"makes" + '
#   '0.011*"food_great" + 0.010*"hope" + 0.010*"simply" + 0.009*"place" + '
#   '0.009*"keep" + 0.009*"food" + 0.009*"slightly" + 0.008*"good" + '
#   '0.008*"week" + 0.008*"indian_places" + 0.008*"perfect" + 0.008*"short" + '
#   '0.008*"tandoori_chicken" + 0.007*"cream" + 0.007*"really_enjoyed" + '
#   '0.007*"trip" + 0.007*"chicken_curry" + 0.007*"indian" + 0.006*"really_nice" '
#   '+ 0.006*"yet" + 0.006*"plate" + 0.006*"gave_us"'),
#  (3,
#   '0.028*"visit" + 0.027*"indian_buffet" + 0.021*"coming" + 0.018*"type" + '
#   '0.018*"saw" + 0.018*"felt_like" + 0.017*"mixed" + 0.017*"nan" + '
#   '0.016*"spice_level" + 0.016*"salad" + 0.014*"drinks" + 0.014*"choices" + '
#   '0.012*"live" + 0.012*"charge" + 0.011*"taken" + 0.010*"anyone" + '
#   '0.009*"priced" + 0.009*"madison" + 0.009*"appetizer" + 0.009*"treat" + '
#   '0.009*"would_give" + 0.008*"additional" + 0.008*"bollywood" + 0.008*"odd" + '
#   '0.008*"tv" + 0.008*"hoping" + 0.007*"thai" + 0.007*"continue" + '
#   '0.007*"food_always" + 0.006*"rate"'),
#  (4,
#   '0.022*"butter_chicken" + 0.016*"lunch" + 0.014*"quite" + 0.013*"lamb" + '
#   '0.013*"return" + 0.013*"come" + 0.012*"waitress" + 0.012*"going_back" + '
#   '0.012*"top" + 0.011*"closed" + 0.011*"definitely_back" + 0.011*"liked" + '
#   '0.011*"need" + 0.010*"authentic_indian" + 0.010*"groupon" + '
#   '0.009*"service_good" + 0.009*"serving" + 0.009*"craving" + '
#   '0.008*"weekday_lunch" + 0.008*"bit" + 0.008*"dhaba" + 0.008*"buffet" + '
#   '0.008*"ordered_lamb" + 0.008*"one_thing" + 0.008*"ordered" + '
#   '0.007*"would_go" + 0.007*"back" + 0.007*"comes" + 0.007*"food" + '
#   '0.007*"run"'),
#  (5,
#   '0.017*"find" + 0.014*"served" + 0.012*"left" + 0.012*"little" + '
#   '0.012*"like" + 0.012*"would" + 0.011*"told" + 0.011*"take" + 0.011*"water" '
#   '+ 0.010*"veggie" + 0.010*"surprised" + 0.009*"fact" + 0.009*"read" + '
#   '0.009*"worth" + 0.008*"one" + 0.007*"whole" + 0.007*"decided_try" + '
#   '0.007*"eating" + 0.007*"even" + 0.007*"reason" + 0.007*"yogurt" + '
#   '0.007*"stuff" + 0.006*"taste" + 0.006*"however" + 0.006*"man" + '
#   '0.006*"everything_else" + 0.006*"cook" + 0.006*"literally" + '
#   '0.006*"request" + 0.006*"amount"'),
#  (6,
#   '0.030*"good" + 0.021*"curry" + 0.019*"also" + 0.014*"service" + '
#   '0.011*"place" + 0.011*"real" + 0.011*"spicy" + 0.010*"get" + 0.009*"way" + '
#   '0.009*"big" + 0.009*"indian" + 0.009*"price" + 0.008*"decor" + '
#   '0.008*"little" + 0.008*"plus" + 0.008*"go" + 0.008*"today" + '
#   '0.008*"nothing" + 0.008*"plenty" + 0.008*"fried" + 0.007*"great" + '
#   '0.007*"asked" + 0.007*"choice" + 0.007*"cooking" + 0.007*"based" + '
#   '0.006*"soft" + 0.006*"veggies" + 0.006*"friends" + 0.006*"cut" + '
#   '0.006*"may"'),
#  (7,
#   '0.015*"star" + 0.014*"group" + 0.013*"less" + 0.012*"nicely" + '
#   '0.012*"usual" + 0.012*"offered" + 0.011*"soon" + 0.011*"food" + '
#   '0.011*"working" + 0.010*"ready" + 0.010*"staff" + 0.009*"miss" + '
#   '0.009*"often" + 0.009*"helpful" + 0.009*"given" + 0.009*"many_indian" + '
#   '0.009*"went_dinner" + 0.009*"various" + 0.009*"india" + 0.008*"waiting" + '
#   '0.008*"part" + 0.008*"without" + 0.007*"main" + 0.007*"masala_chicken" + '
#   '0.007*"samosas" + 0.007*"smell" + 0.006*"original" + 0.006*"use" + '
#   '0.006*"meat_dishes" + 0.006*"hours"'),
#  (8,
#   '0.029*"chicken" + 0.026*"vegetarian" + 0.018*"everything" + 0.014*"small" + '
#   '0.012*"butter" + 0.011*"atmosphere" + 0.011*"mostly" + 0.011*"looked" + '
#   '0.010*"quick" + 0.010*"town" + 0.010*"add" + 0.010*"kids" + 0.010*"veg" + '
#   '0.010*"great_food" + 0.009*"perhaps" + 0.008*"great_indian" + '
#   '0.008*"version" + 0.008*"like" + 0.008*"also_tried" + 0.008*"maybe" + '
#   '0.008*"delicious" + 0.008*"lentils" + 0.007*"chana_masala" + '
#   '0.007*"seriously" + 0.007*"stuffed" + 0.007*"potatoes" + 0.007*"ambiance" + '
#   '0.006*"service_really" + 0.006*"lunch" + 0.006*"gobi"'),
#  (9,
#   '0.042*"food" + 0.018*"best_indian" + 0.017*"staff" + 0.013*"indian" + '
#   '0.011*"better" + 0.011*"back" + 0.011*"actually" + 0.010*"care" + '
#   '0.009*"work" + 0.009*"arrived" + 0.009*"place" + 0.009*"restaurant" + '
#   '0.009*"night" + 0.008*"things" + 0.008*"time" + 0.008*"bring" + '
#   '0.008*"style" + 0.008*"really" + 0.008*"go" + 0.008*"order" + '
#   '0.007*"decided" + 0.007*"took" + 0.007*"interesting" + 0.006*"chai" + '
#   '0.006*"enjoy" + 0.006*"many" + 0.006*"would" + 0.006*"longer" + '
#   '0.006*"noticed" + 0.006*"even"'),
#  (10,
#   '0.022*"one" + 0.019*"indian_restaurants" + 0.015*"new" + 0.013*"clean" + '
#   '0.011*"one_best" + 0.011*"start" + 0.010*"set" + 0.009*"serve" + '
#   '0.009*"kitchen" + 0.009*"available" + 0.008*"owners" + 0.008*"still" + '
#   '0.008*"bill" + 0.008*"went" + 0.007*"like" + 0.007*"rest" + 0.007*"us" + '
#   '0.007*"forget" + 0.007*"finished" + 0.007*"busy" + 0.006*"gave" + '
#   '0.006*"absolutely" + 0.006*"indian_restaurant" + 0.006*"said" + '
#   '0.006*"looking" + 0.006*"twice" + 0.006*"leave" + 0.006*"completely" + '
#   '0.006*"indian" + 0.006*"later"'),
#  (11,
#   '0.030*"food" + 0.024*"indian_food" + 0.023*"place" + 0.021*"never" + '
#   '0.018*"restaurant" + 0.016*"good_indian" + 0.013*"indian" + 0.013*"buffet" '
#   '+ 0.013*"good" + 0.013*"feel" + 0.012*"biryani" + 0.011*"fresh" + '
#   '0.011*"food_really" + 0.010*"make_sure" + 0.010*"buffets" + 0.010*"last" + '
#   '0.010*"call" + 0.009*"disappointed" + 0.009*"true" + '
#   '0.009*"indian_restaurant" + 0.008*"choose" + 0.008*"best_indian" + '
#   '0.007*"indian_buffets" + 0.007*"taj" + 0.007*"always" + 0.007*"party" + '
#   '0.007*"must" + 0.007*"person" + 0.006*"service" + 0.006*"thinking"'),
#  (12,
#   '0.032*"buffet" + 0.020*"lunch_buffet" + 0.019*"great" + 0.018*"dinner" + '
#   '0.017*"definitely" + 0.015*"meal" + 0.015*"good" + 0.014*"garlic_naan" + '
#   '0.011*"food" + 0.011*"taste" + 0.011*"indian" + 0.010*"nice" + '
#   '0.010*"experience" + 0.010*"side" + 0.009*"something" + 0.008*"place" + '
#   '0.008*"see" + 0.007*"ever" + 0.007*"delicious" + 0.007*"pretty_good" + '
#   '0.007*"end" + 0.007*"every" + 0.007*"indian_food" + 0.007*"sure" + '
#   '0.007*"wait" + 0.007*"full" + 0.007*"sweet" + 0.007*"get" + 0.007*"made" + '
#   '0.006*"reviews"'),
#  (13,
#   '0.027*"restaurant" + 0.016*"open" + 0.013*"business" + 0.013*"three" + '
#   '0.012*"know" + 0.012*"great_place" + 0.011*"large" + 0.010*"low" + '
#   '0.010*"dry" + 0.009*"clearly" + 0.009*"server" + 0.008*"eat" + '
#   '0.008*"making" + 0.008*"highly" + 0.008*"problem" + 0.008*"considering" + '
#   '0.008*"like" + 0.008*"could" + 0.007*"door" + 0.007*"place" + '
#   '0.007*"really" + 0.007*"forgot" + 0.007*"restaurants" + 0.007*"gone" + '
#   '0.007*"gulab" + 0.007*"go" + 0.007*"turned" + 0.007*"unfortunately" + '
#   '0.007*"next_time" + 0.006*"another"'),
#  (14,
#   '0.025*"dishes" + 0.022*"like" + 0.016*"food" + 0.016*"review" + 0.015*"eat" '
#   '+ 0.015*"might" + 0.014*"long" + 0.013*"indian" + 0.011*"overall" + '
#   '0.011*"seem" + 0.010*"mango" + 0.010*"especially" + 0.010*"mint" + '
#   '0.010*"one" + 0.009*"entrees" + 0.009*"manager" + 0.008*"quality_food" + '
#   '0.008*"fast_food" + 0.008*"look" + 0.008*"get" + 0.007*"desserts" + '
#   '0.007*"around" + 0.007*"little" + 0.007*"tikka_masala" + 0.007*"food_came" '
#   '+ 0.007*"also" + 0.007*"customers" + 0.007*"kinda" + 0.007*"go" + '
#   '0.006*"authentic"'),
#  (15,
#   '0.018*"food" + 0.017*"best" + 0.015*"tasty" + 0.014*"good" + 0.013*"indian" '
#   '+ 0.012*"place" + 0.012*"loved" + 0.011*"go_back" + 0.011*"chicken" + '
#   '0.010*"lots" + 0.010*"decent" + 0.010*"great" + 0.009*"cuisine" + '
#   '0.008*"location" + 0.008*"due" + 0.008*"love_indian" + 0.008*"spices" + '
#   '0.007*"soup" + 0.007*"guess" + 0.007*"get" + 0.007*"trying" + 0.006*"hard" '
#   '+ 0.006*"perfectly" + 0.006*"ordered" + 0.006*"plain" + 0.006*"fish" + '
#   '0.006*"meals" + 0.006*"think" + 0.006*"simple" + 0.006*"option"'),
#  (16,
#   '0.025*"go" + 0.018*"food" + 0.017*"place" + 0.016*"since" + 0.013*"us" + '
#   '0.013*"flavor" + 0.012*"first_time" + 0.012*"restaurant" + 0.012*"good" + '
#   '0.011*"garlic" + 0.010*"times" + 0.010*"ordered_chicken" + 0.009*"wife" + '
#   '0.009*"like" + 0.009*"ask" + 0.009*"menu" + 0.008*"pretty" + 0.008*"also" + '
#   '0.008*"selection" + 0.008*"went" + 0.008*"glad" + 0.008*"indian_food" + '
#   '0.007*"heat" + 0.007*"everyone" + 0.006*"walk" + 0.006*"pick" + '
#   '0.006*"happy" + 0.006*"called" + 0.006*"order" + 0.006*"chili"'),
#  (17,
#   '0.023*"want" + 0.018*"check" + 0.017*"close" + 0.015*"although" + '
#   '0.014*"fantastic" + 0.013*"mango_lassi" + 0.011*"minutes" + 0.011*"someone" '
#   '+ 0.010*"excellent" + 0.009*"yelp" + 0.009*"beef" + 0.009*"portion" + '
#   '0.009*"quickly" + 0.009*"guy" + 0.009*"number" + 0.009*"bowl" + '
#   '0.008*"food_pretty" + 0.008*"place" + 0.008*"sitting" + 0.008*"packed" + '
#   '0.008*"seated" + 0.007*"thanks" + 0.007*"incredibly" + 0.007*"weird" + '
#   '0.007*"like" + 0.007*"expect" + 0.007*"middle" + 0.006*"table" + '
#   '0.006*"plates" + 0.006*"rice"'),
#  (18,
#   '0.045*"food" + 0.020*"well" + 0.014*"usually" + 0.013*"thought" + '
#   '0.013*"make" + 0.013*"tables" + 0.013*"place" + 0.012*"come" + '
#   '0.012*"curries" + 0.012*"quality" + 0.011*"naan_bread" + '
#   '0.010*"really_good" + 0.010*"buffet" + 0.009*"naan" + '
#   '0.009*"highly_recommend" + 0.009*"food_service" + 0.008*"staff_friendly" + '
#   '0.008*"lunch_buffet" + 0.008*"full" + 0.008*"opened" + 0.008*"eaten" + '
#   '0.008*"went" + 0.008*"cheap" + 0.008*"used" + 0.008*"free" + 0.007*"get" + '
#   '0.007*"extra" + 0.007*"would" + 0.006*"cold" + 0.006*"great_service"'),
#  (19,
#   '0.016*"sauces" + 0.015*"love" + 0.014*"inside" + 0.014*"second" + '
#   '0.013*"lovely" + 0.013*"food_good" + 0.013*"come_back" + 0.012*"bar" + '
#   '0.012*"away" + 0.010*"food" + 0.010*"service" + 0.010*"buffet" + '
#   '0.009*"guys" + 0.009*"chinese" + 0.009*"slow" + 0.008*"indian_food" + '
#   '0.008*"average" + 0.008*"coming_back" + 0.008*"great" + 0.008*"extremely" + '
#   '0.008*"day" + 0.007*"regular" + 0.007*"definitely_worth" + 0.007*"room" + '
#   '0.007*"place" + 0.007*"ate" + 0.006*"sit" + 0.006*"come" + '
#   '0.006*"good_service" + 0.006*"get"')]

# %% [markdown]
# Phrase extraction (using n-grams

# %%
import nltk
from nltk.util import ngrams
from collections import Counter
unigram_counter = Counter()
bigram_counter = Counter()
trigram_counter = Counter()
four_gram_counter = Counter()
five_gram_counter = Counter()

# %%
for sent in sent_stream:
    unigram = ngrams(sent, 1)
    for each in unigram:
        unigram_counter[each] += 1
#unigram_counter.most_common(300)

# %%
for sent in sent_stream:
    bigram = ngrams(sent, 2)
    for each in bigram:
        bigram_counter[each] += 1
bigram_counter.most_common(300)
# Out:
# [(('indian', 'food'), 1970),
#  (('lunch', 'buffet'), 1001),
#  (('chicken', 'tikka'), 981),
#  (('tikka', 'masala'), 674),
#  (('indian', 'restaurant'), 641),
#  (('best', 'indian'), 622),
#  (('garlic', 'naan'), 606),
#  (('indian', 'restaurants'), 535),
#  (('tandoori', 'chicken'), 365),
#  (('go', 'back'), 332),
#  (('first', 'time'), 320),
#  (('good', 'indian'), 314),
#  (('mango', 'lassi'), 230),
#  (('food', 'good'), 220),
#  (('really', 'good'), 211),
#  (('naan', 'bread'), 208),
#  (('south', 'indian'), 207),
#  (('favorite', 'indian'), 200),
#  (('come', 'back'), 200),
#  (('indian', 'buffet'), 194),
#  (('one', 'best'), 191),
#  (('butter', 'chicken'), 189),
#  (('ordered', 'chicken'), 184),
#  (('even', 'though'), 180),
#  (('indian', 'cuisine'), 180),
#  (('indian', 'place'), 179),
#  (('highly', 'recommend'), 179),
#  (('next', 'time'), 177),
#  (('good', 'food'), 173),
#  (('love', 'indian'), 170),
#  (('chicken', 'curry'), 168),
#  (('like', 'indian'), 167),
#  (('food', 'service'), 165),
#  (('food', 'really'), 160),
#  (('great', 'food'), 159),
#  (('pretty', 'good'), 157),
#  (('las', 'vegas'), 155),
#  (('every', 'time'), 146),
#  (('food', 'great'), 146),
#  (('going', 'back'), 144),
#  (('make', 'sure'), 142),
#  (('went', 'lunch'), 137),
#  (('authentic', 'indian'), 136),
#  (('staff', 'friendly'), 134),
#  (('better', 'indian'), 133),
#  (('tasted', 'like'), 130),
#  (('little', 'bit'), 128),
#  (('would', 'recommend'), 126),
#  (('basmati', 'rice'), 124),
#  (('indian', 'places'), 124),
#  (('great', 'place'), 123),
#  (('great', 'indian'), 118),
#  (('indian', 'buffets'), 118),
#  (('craving', 'indian'), 114),
#  (('pretty', 'much'), 114),
#  (('really', 'enjoyed'), 113),
#  (('coming', 'back'), 113),
#  (('much', 'better'), 113),
#  (('quality', 'food'), 113),
#  (('saag', 'paneer'), 112),
#  (('feel', 'like'), 112),
#  (('great', 'service'), 111),
#  (('would', 'definitely'), 111),
#  (('rice', 'pudding'), 108),
#  (('indian', 'lunch'), 107),
#  (('felt', 'like'), 106),
#  (('food', 'ever'), 105),
#  (('palak', 'paneer'), 104),
#  (('india', 'palace'), 104),
#  (('also', 'ordered'), 103),
#  (('chicken', 'chicken'), 103),
#  (('one', 'favorite'), 103),
#  (('last', 'night'), 102),
#  (('service', 'great'), 102),
#  (('definitely', 'go'), 100),
#  (('many', 'indian'), 99),
#  (('recommend', 'place'), 99),
#  (('would', 'go'), 97),
#  (('lamb', 'vindaloo'), 97),
#  (('service', 'food'), 96),
#  (('service', 'friendly'), 96),
#  (('last', 'time'), 96),
#  (('strip', 'mall'), 95),
#  (('food', 'always'), 94),
#  (('service', 'good'), 93),
#  (('back', 'try'), 91),
#  (('really', 'like'), 90),
#  (('good', 'service'), 90),
#  (('gulab', 'jamun'), 89),
#  (('food', 'pretty'), 89),
#  (('wait', 'staff'), 88),
#  (('well', 'worth'), 88),
#  (('looks', 'like'), 86),
#  (('malai', 'kofta'), 86),
#  (('give', 'place'), 84),
#  (('wait', 'go'), 84),
#  (('lamb', 'curry'), 83),
#  (('best', 'ever'), 82),
#  (('gave', 'us'), 81),
#  (('customer', 'service'), 81),
#  (('indian', 'dishes'), 81),
#  (('really', 'nice'), 80),
#  (('decided', 'try'), 80),
#  (('food', 'place'), 80),
#  (('rice', 'naan'), 80),
#  (('good', 'place'), 79),
#  (('would', 'like'), 79),
#  (('vegetarian', 'dishes'), 78),
#  (('seemed', 'like'), 78),
#  (('try', 'something'), 78),
#  (('spice', 'level'), 78),
#  (('ordered', 'lamb'), 78),
#  (('tandoori', 'times'), 78),
#  (('went', 'back'), 76),
#  (('chicken', 'vindaloo'), 76),
#  (('looked', 'like'), 75),
#  (('looking', 'forward'), 75),
#  (('told', 'us'), 75),
#  (('goat', 'curry'), 74),
#  (('food', 'would'), 74),
#  (('would', 'say'), 74),
#  (('chicken', 'tikki'), 74),
#  (('really', 'liked'), 73),
#  (('reasonably', 'priced'), 73),
#  (('chicken', 'korma'), 73),
#  (('new', 'indian'), 72),
#  (('everything', 'else'), 72),
#  (('north', 'indian'), 72),
#  (('try', 'place'), 72),
#  (('chicken', 'lamb'), 71),
#  (('try', 'lunch'), 71),
#  (('curry', 'chicken'), 70),
#  (('buffet', 'food'), 70),
#  (('found', 'place'), 70),
#  (('went', 'dinner'), 69),
#  (('wanted', 'try'), 69),
#  (('paneer', 'tikka'), 68),
#  (('big', 'fan'), 68),
#  (('definitely', 'recommend'), 68),
#  (('lamb', 'chicken'), 68),
#  (('chicken', 'dishes'), 67),
#  (('chicken', 'tandoori'), 67),
#  (('several', 'times'), 67),
#  (('brought', 'us'), 67),
#  (('service', 'always'), 66),
#  (('like', 'food'), 66),
#  (('buffet', 'great'), 66),
#  (('fan', 'indian'), 65),
#  (('definitely', 'back'), 65),
#  (('food', 'delicious'), 65),
#  (('food', 'came'), 65),
#  (('go', 'indian'), 65),
#  (('came', 'back'), 64),
#  (('one', 'thing'), 64),
#  (('place', 'go'), 64),
#  (('buffet', 'good'), 64),
#  (('great', 'great'), 63),
#  (('dinner', 'buffet'), 63),
#  (('eat', 'indian'), 62),
#  (('definitely', 'worth'), 62),
#  (('place', 'really'), 60),
#  (('dining', 'room'), 60),
#  (('right', 'amount'), 60),
#  (('decided', 'give'), 59),
#  (('look', 'forward'), 59),
#  (('masala', 'chicken'), 59),
#  (('also', 'tried'), 59),
#  (('try', 'new'), 58),
#  (('chicken', 'masala'), 58),
#  (('chana', 'masala'), 58),
#  (('many', 'times'), 58),
#  (('royal', 'taj'), 58),
#  (('vegetarian', 'options'), 58),
#  (('every', 'dish'), 57),
#  (('lot', 'indian'), 57),
#  (('good', 'good'), 57),
#  (('probably', 'best'), 57),
#  (('tried', 'indian'), 57),
#  (('fast', 'food'), 57),
#  (('second', 'time'), 57),
#  (('every', 'indian'), 56),
#  (('try', 'indian'), 56),
#  (('really', 'great'), 56),
#  (('would', 'give'), 56),
#  (('never', 'tried'), 56),
#  (('could', 'eat'), 56),
#  (('couple', 'times'), 56),
#  (('india', 'oven'), 56),
#  (('got', 'chicken'), 55),
#  (('food', 'buffet'), 55),
#  (('definitely', 'come'), 55),
#  (('long', 'time'), 54),
#  (('buffet', 'lunch'), 54),
#  (('place', 'good'), 54),
#  (('looking', 'good'), 54),
#  (('next', 'door'), 53),
#  (('naan', 'good'), 53),
#  (('traditional', 'indian'), 53),
#  (('tikki', 'masala'), 53),
#  (('lamb', 'korma'), 53),
#  (('chicken', 'biryani'), 53),
#  (('far', 'best'), 53),
#  (('food', 'best'), 53),
#  (('food', 'one'), 53),
#  (('good', 'selection'), 53),
#  (('ice', 'cream'), 52),
#  (('taj', 'mahal'), 52),
#  (('never', 'indian'), 52),
#  (('love', 'food'), 52),
#  (('taste', 'like'), 52),
#  (('pleasantly', 'surprised'), 52),
#  (('food', 'like'), 52),
#  (('food', 'definitely'), 52),
#  (('food', 'quality'), 52),
#  (('service', 'really'), 51),
#  (('lamb', 'dish'), 51),
#  (('great', 'lunch'), 51),
#  (('place', 'food'), 51),
#  (('food', 'spicy'), 51),
#  (('origin', 'india'), 51),
#  (('definitely', 'going'), 50),
#  (('eating', 'indian'), 50),
#  (('indian', 'music'), 50),
#  (('chai', 'tea'), 50),
#  (('bombay', 'spice'), 50),
#  (('never', 'seen'), 49),
#  (('delicious', 'food'), 49),
#  (('always', 'get'), 49),
#  (('weekday', 'lunch'), 49),
#  (('aloo', 'gobi'), 49),
#  (('get', 'food'), 49),
#  (('spicy', 'food'), 49),
#  (('want', 'try'), 49),
#  (('naan', 'also'), 48),
#  (('delhi', 'palace'), 48),
#  (('could', 'get'), 48),
#  (('place', 'great'), 48),
#  (('would', 'come'), 48),
#  (('seems', 'like'), 48),
#  (('meat', 'dishes'), 47),
#  (('best', 'part'), 47),
#  (('food', 'served'), 47),
#  (('lunch', 'time'), 47),
#  (('rogan', 'josh'), 47),
#  (('food', 'fresh'), 46),
#  (('new', 'favorite'), 46),
#  (('chicken', 'makhani'), 46),
#  (('great', 'selection'), 46),
#  (('good', 'quality'), 46),
#  (('food', 'excellent'), 45),
#  (('time', 'went'), 45),
#  (('decent', 'indian'), 45),
#  (('huge', 'fan'), 45),
#  (('first', 'visit'), 45),
#  (('tikka', 'chicken'), 45),
#  (('la', 'carte'), 45),
#  (('find', 'indian'), 45),
#  (('love', 'place'), 45),
#  (('food', 'tasty'), 45),
#  (('restaurant', 'las'), 45),
#  (('india', 'masala'), 45),
#  (('food', 'food'), 44),
#  (('took', 'minutes'), 44),
#  (('plain', 'naan'), 44),
#  (('chicken', 'tika'), 44),
#  (('service', 'also'), 44),
#  (('guru', 'palace'), 44),
#  (('also', 'good'), 43),
#  (('service', 'little'), 43),
#  (('lunch', 'buffets'), 43),
#  (('good', 'thing'), 43),
#  (('place', 'indian'), 43),
#  (('nan', 'bread'), 43),
#  (('hard', 'find'), 43),
#  (('decided', 'go'), 43),
#  (('food', 'court'), 43),
#  (('go', 'wrong'), 42),
#  (('typical', 'indian'), 42),
#  (('place', 'pretty'), 42),
#  (('really', 'enjoy'), 42),
#  (('like', 'place'), 42),
#  (('tried', 'chicken'), 42),
#  (('must', 'say'), 42),
#  (('go', 'lunch'), 42),
#  (('really', 'really'), 42),
#  (('good', 'variety'), 41),
#  (('place', 'like'), 41),
#  (('fresh', 'naan'), 41),
#  (('another', 'indian'), 41),
#  (('eaten', 'indian'), 41),
#  (('indian', 'style'), 41),
#  (('delicious', 'indian'), 41),
#  (('real', 'indian'), 41),
#  (('friday', 'night'), 41),
#  (('parking', 'lot'), 41),
#  (('ordered', 'garlic'), 41),
#  (('favorite', 'dish'), 41),
#  (('dinner', 'menu'), 41),
#  (('food', 'even'), 41),
#  (('restaurant', 'clean'), 41)]

# %%
for sent in sent_stream:
    trigram = ngrams(sent, 3)
    for each in trigram:
        trigram_counter[each] += 1
trigram_counter.most_common(100)
# Out:
# [(('chicken', 'tikka', 'masala'), 968),
#  (('best', 'indian', 'food'), 600),
#  (('good', 'indian', 'food'), 188),
#  (('indian', 'food', 'ever'), 188),
#  (('best', 'indian', 'restaurant'), 172),
#  (('ordered', 'chicken', 'tikka'), 154),
#  (('one', 'best', 'indian'), 140),
#  (('love', 'indian', 'food'), 134),
#  (('favorite', 'indian', 'restaurant'), 126),
#  (('went', 'lunch', 'buffet'), 118),
#  (('indian', 'lunch', 'buffet'), 100),
#  (('craving', 'indian', 'food'), 100),
#  (('indian', 'food', 'place'), 100),
#  (('many', 'indian', 'restaurants'), 96),
#  (('like', 'indian', 'food'), 90),
#  (('go', 'back', 'try'), 82),
#  (('indian', 'restaurant', 'las'), 80),
#  (('best', 'indian', 'restaurants'), 76),
#  (('wait', 'go', 'back'), 76),
#  (('definitely', 'go', 'back'), 76),
#  (('chicken', 'tikki', 'masala'), 74),
#  (('south', 'indian', 'food'), 74),
#  (('best', 'indian', 'buffet'), 72),
#  (('definitely', 'come', 'back'), 70),
#  (('chicken', 'tikka', 'chicken'), 70),
#  (('indian', 'food', 'las'), 70),
#  (('would', 'highly', 'recommend'), 68),
#  (('chicken', 'chicken', 'tikka'), 68),
#  (('authentic', 'indian', 'food'), 68),
#  (('better', 'indian', 'food'), 66),
#  (('would', 'definitely', 'recommend'), 66),
#  (('tikka', 'masala', 'chicken'), 62),
#  (('eat', 'indian', 'food'), 62),
#  (('looking', 'good', 'indian'), 62),
#  (('far', 'best', 'indian'), 62),
#  (('every', 'indian', 'restaurant'), 60),
#  (('favorite', 'indian', 'food'), 58),
#  (('lunch', 'buffet', 'good'), 58),
#  (('lunch', 'buffet', 'great'), 58),
#  (('paneer', 'tikka', 'masala'), 56),
#  (('try', 'lunch', 'buffet'), 56),
#  (('would', 'recommend', 'place'), 54),
#  (('one', 'favorite', 'indian'), 54),
#  (('would', 'go', 'back'), 52),
#  (('good', 'indian', 'restaurant'), 52),
#  (('indian', 'food', 'since'), 52),
#  (('would', 'definitely', 'go'), 52),
#  (('really', 'good', 'indian'), 50),
#  (('never', 'indian', 'food'), 50),
#  (('fan', 'indian', 'food'), 50),
#  (('great', 'indian', 'food'), 50),
#  (('lamb', 'rogan', 'josh'), 50),
#  (('garlic', 'naan', 'bread'), 48),
#  (('indian', 'food', 'restaurant'), 48),
#  (('first', 'time', 'went'), 48),
#  (('tried', 'lunch', 'buffet'), 48),
#  (('better', 'indian', 'restaurants'), 48),
#  (('got', 'chicken', 'tikka'), 46),
#  (('food', 'good', 'service'), 46),
#  (('back', 'next', 'time'), 44),
#  (('nothing', 'write', 'home'), 44),
#  (('food', 'really', 'good'), 44),
#  (('tried', 'indian', 'food'), 44),
#  (('hands', 'best', 'indian'), 44),
#  (('free', 'mango', 'lassi'), 44),
#  (('lunch', 'buffet', 'food'), 42),
#  (('chicken', 'tika', 'masala'), 42),
#  (('never', 'tried', 'indian'), 42),
#  (('indian', 'food', 'like'), 42),
#  (('indian', 'food', 'vegas'), 42),
#  (('keep', 'coming', 'back'), 42),
#  (('mint', 'indian', 'bistro'), 42),
#  (('garlic', 'naan', 'chicken'), 40),
#  (('eaten', 'indian', 'food'), 40),
#  (('first', 'time', 'eating'), 40),
#  (('indian', 'food', 'one'), 40),
#  (('indian', 'food', 'good'), 40),
#  (('tandoori', 'chicken', 'chicken'), 40),
#  (('definitely', 'coming', 'back'), 40),
#  (('highly', 'recommend', 'place'), 40),
#  (('come', 'back', 'try'), 40),
#  (('great', 'food', 'great'), 40),
#  (('much', 'better', 'indian'), 38),
#  (('first', 'time', 'trying'), 38),
#  (('indian', 'food', 'always'), 38),
#  (('indian', 'food', 'really'), 38),
#  (('ordered', 'garlic', 'naan'), 38),
#  (('indian', 'restaurants', 'around'), 38),
#  (('mango', 'ice', 'cream'), 36),
#  (('tikka', 'masala', 'garlic'), 36),
#  (('indian', 'lunch', 'buffets'), 36),
#  (('weekday', 'lunch', 'buffet'), 36),
#  (('indian', 'food', 'first'), 36),
#  (('definitely', 'going', 'back'), 36),
#  (('indian', 'food', 'places'), 36),
#  (('chicken', 'tikka', 'lamb'), 36),
#  (('north', 'south', 'indian'), 36),
#  (('another', 'indian', 'restaurant'), 34),
#  (('indian', 'restaurant', 'ever'), 34),
#  (('eating', 'indian', 'food'), 34)]
